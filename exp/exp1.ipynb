# %% [markdown]
# # Experimentación 1: Tiempos
#
# Se corrio fuerza bruta para distinto W tomando wi random entre 1 y 3/4W

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os

# import scripts.utils as utilsNo numeric types to aggregate


# sns.set(style='darkgrid')
os.system("mkdir -p graficos")
os.getcwd()
# for dir in os.walk("."):
#     print (dir)
# Out:
# '/home/santi/exactas/so/tp2/exp'

# %%
def getStd(pd):
    return pd.sem(axis=1).mean()

np.dtype(float)
# Out:
# dtype('float64')

# %%
df = pd.read_csv('results.csv', delimiter=",")

df
# Out:
#     dificultad  nodos  tiempo
# 0            5      4    2.30
# 1            5      4    2.28
# 2            5      4    2.30
# 3            5     32    7.83
# 4            5     32    7.40
# 5            5     32    7.65
# 6            5     64  184.82
# 7            5     64  238.92
# 8            5     64  224.00
# 9           15      4   92.81
# 10          15      4   94.38
# 11          15      4   85.22
# 12          15     32  101.96
# 13          15     32  105.47
# 14          15     32   89.87
# 15          15     64   95.64
# 16          15     64  105.79
# 17          15     64  101.84
# 18           3      4    2.26
# 19           3      4    2.22
# 20           3      4    2.18
# 21           3     32   77.94
# 22           3     32   70.13
# 23           3     32   76.59
# 24           3     64  328.34
# 25           3     64  356.63
# 26           3     64  352.36
# 27           7      4    2.53
# 28           7      4    2.51
# 29           7      4    2.58
# ...

# %%
def graficar(df,nombre):
    ax = sns.lineplot(x = 'n', y = 't', ci="sd", hue="", data=df)
#    ax = sns.scatterplot(x = 'n', y = 'time', hue='col', data=dfm)
    ax.get_figure().savefig('graficos/{}.png'.format(nombre))

# %%
### graficar



# dff = df[(df['a'] == 'tree') & (df['n'] < 15000) & (df['k'].isin(kvalues)) ]

nvalues = [4,32]
dff = df.copy()[df['nodos'].isin(nvalues)]



ax = sns.relplot(x = 'dificultad', y = 'tiempo', hue='nodos', data=dff,kind='line', legend="full")


ax.savefig('graficos/{}.png'.format('grafico'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-72302b6a8b35> in <module>
#      10
#      11
# ---> 12 ax = sns.relplot(x = 'dificultad', y = 'tiempo', hue='nodos', ci=std,data=dff,kind='line', legend="full")
#      13
#      14
#
# NameError: name 'std' is not defined

# %%
### graficar

kvalues = df['k'].unique()

print(kvalues)
kvalues = [10,50,100,500,1000,3000,]

dff = df[(df['n'] < 80 ** 2) & (df['k'] == 30000) ]

print(dff['n'].unique())


ax = sns.relplot(x = 'n', y = 't', hue='a', data=dff,kind='line', legend=None)

plt.legend( ['array', 'tree', 'relinking'])
legend.texts[0].set_text("Whatever else")
ax.savefig('graficos/{}.png'.format('kruskal2'))
# Out:
# [   10    50   100   200   500  1000  3000  5000 10000 30000]
# [ 100  400  900 2500 3600 4900]

# %%
dff = df.copy()[(df['a'] == 'array') & (df['k'] == 100) & (df['n'] > 1)]
dff["cota"] = df['n'] ** 2
ax1 = sns.lmplot(x='t', y='cota', data=dff);
plt.xlabel("T(n)");
plt.ylabel("cota(n)");

r = np.corrcoef(dff["t"], dff["cota"])[0, 1];
print("El coeficiente de correlación de Pearson es: r="+str(r))

print(dff['a'].unique())
print(dff['k'].unique())
print(dff.shape)

# ax1.savefig('graficos/{}.png'.format('corrTree30000'))
# Out:
# El coeficiente de correlación de Pearson es: r=0.9999523258742676
# ['array']
# [100]
# (1400, 5)

# %%
dff = df.copy()[(df['a'] == 'tree') & (df['k'] == 500) & (df['n'] < 1000000000)]
dff["cota"] = df['n'] * np.log2(df['n'])
ax1 = sns.lmplot(x='t', y='cota', data=dff);
plt.xlabel("T(n)");
plt.ylabel("cota(n)");

r = np.corrcoef(dff["t"], dff["cota"])[0, 1];
print("El coeficiente de correlación de Pearson es: r="+str(r))

print(dff['a'].unique())
print(dff['k'].unique())

# ax1.savefig('graficos/{}.png'.format('corrTree6'))
# Out:
# El coeficiente de correlación de Pearson es: r=0.9959376250582227
# ['tree']
# [500]
